# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n = 1000
x = np.arange(n,dtype=float)
x *= 2.0 * np.pi/(n-1)

# %%
x = np.arange(0,2*np.pi,.1)
y = np.arange(-1,10,.1)
plt.plot(5.5 * np.cos(2*x) + 5.5)
plt.plot(0.02 * np.exp(x))
plt.plot(0.25 * x**2 + 0.1 * np.sin(10*x))
plt.xlabel('Measure of Awesomeness')
plt.ylabel('Time in ASTR/EART 119')
plt.show()
